# %%
#Load required libraries
import pandas as pd
import os
import numpy as np

# %%
#Change directory
os.chdir('/Users/manikantanvenkataraman/Downloads')
os.getcwd()
# Out:
# '/Users/manikantanvenkataraman/Downloads'

# %%
# Question 1
# Load data from csv file into dataframe
vgames_df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv.zip")

# %%
# Question 2
#Diplay first 10 rows of the data set
vgames_df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
# Question 3
# Dataframe dimensions - Size
vgames_df.size # Size is the number of rows multiplied by number of columns
# Out:
# 267504

# %%
# Question 3
# Dataframe dimensions - Shape
vgames_df.shape # Shape gives the number of rows, number of columns respectively.

# In the given data set, number of rows represent the number of games 
# and number of columns represent several information about the games.
# Out:
# (16719, 16)

# %%
# Question 3
# Dataframe dimensions - ndim
vgames_df.ndim #ndim gives the number of dimensions in the dataset (rows & columns - hence 2)
# Out:
# 2

# %%
# Question 4
# Overall Top five games based on critic score

vgames_top5 = vgames_df.nlargest(5, 'Critic_Score')
vgames_top5['Name']
# Out:
# 51           Grand Theft Auto IV
# 57           Grand Theft Auto IV
# 227     Tony Hawk's Pro Skater 2
# 5350                 SoulCalibur
# 16            Grand Theft Auto V
# Name: Name, dtype: object

# %%
# Question 5
# Number of video games in the dataframe in each genre

print(vgames_df.groupby('Genre').size())
# Out:
# Genre
# Action          3370
# Adventure       1303
# Fighting         849
# Misc            1750
# Platform         888
# Puzzle           580
# Racing          1249
# Role-Playing    1500
# Shooter         1323
# Simulation       874
# Sports          2348
# Strategy         683
# dtype: int64

# %%
# Question 6
# First ive games in the platform SNES
vgames_snes = vgames_df[vgames_df["Platform"]=='SNES']
vgames_snes.head()
# Out:
#                                      Name Platform  Year_of_Release     Genre  \
# 18                      Super Mario World     SNES           1990.0  Platform
# 56                  Super Mario All-Stars     SNES           1993.0  Platform
# 71                    Donkey Kong Country     SNES           1994.0  Platform
# 76                       Super Mario Kart     SNES           1992.0    Racing
# 137  Street Fighter II: The World Warrior     SNES           1992.0  Fighting
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 18   Nintendo     12.78      3.75      3.54         0.55         20.61
# 56   Nintendo      5.99      2.15      2.12         0.29         10.55
# 71   Nintendo      4.36      1.71      3.00         0.23          9.30
# 76   Nintendo      3.54      1.24      3.81         0.18          8.76
# 137    Capcom      2.47      0.83      2.87         0.12          6.30
#
# ...

# %%
# Question 7
# First five publishers with highest total global sales

vgames_sales = vgames_df.groupby(['Publisher'])['Global_Sales'].sum()
vgames_sales.columns = ['Publisher', 'Global_Sales']
vgames_sales.nlargest(5)
# Out:
# Publisher
# Nintendo                       1788.81
# Electronic Arts                1116.96
# Activision                      731.16
# Sony Computer Entertainment     606.48
# Ubisoft                         471.61
# Name: Global_Sales, dtype: float64

# %%
# Question 8
# Data frame with a new column to determine the percentage of NA sales to Globa Sales

vgames_df1= vgames_df
vgames_df1['NA_Sales_Pct']= (vgames_df1.NA_Sales/vgames_df1.Global_Sales)*100
vgames_df1.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
# Question 9
# Number of nulls in each field 
vgames_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# NA_Sales_Pct          0
# dtype: int64

# %%
# Question 10
# Determine Median for user score

vgames_df.User_Score.median() # #ValueError: could not convert string to float: 'tbd'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     599     if not is_float_dtype(values):
# --> 600         values = values.astype("f8")
#     601         if mask is not None:
#
# ValueError: could not convert string to float: 'tbd'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     122                 try:
# ...

# %%
# Question 10
# Replace tbd with nan and determine Median
vgames_df['User_Score'].replace(['tbd'], np.nan, inplace=True)
vgames_df.User_Score.median()
# Out:
# 7.5

# %%
# Question 10
# Fill in the missing data for user score

vgames_df['User_Score'] = vgames_df['User_Score'].fillna(7.5)
vgames_df.User_Score.unique() # Nan replaced with median value 7.5
# Out:
# array(['8', 7.5, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)
